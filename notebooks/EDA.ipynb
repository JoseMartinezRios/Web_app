# %% [markdown]
# ### First attempt to clear the dataset

# %%
import pandas as pd
import plotly.express as px
import streamlit as st
import os

# %%
path = "../Electric_Vehicle_Registration_Data.csv"
df = pd.read_csv(path)
df.head()
# Out:
#        DATE  NUMBER OF ELECTRIC VEHICLES  VEHICLE MODEL YEAR VEHICLE MAKE  \
# 0  10-01-21                            1                2006       TOYOTA
# 1  10-01-21                            1                2008       TOYOTA
# 2  10-01-21                            1                2009       NISSAN
# 3  10-01-21                            1                2009       TOYOTA
# 4  10-01-21                            1                2011      HYUNDAI
#
#           LOCATION VEHICLE MODEL
# 0   HALIFAX COUNTY           NaN
# 1   HALIFAX COUNTY           NaN
# 2  VICTORIA COUNTY           NaN
# 3   HALIFAX COUNTY           NaN
# 4   HALIFAX COUNTY           NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20177 entries, 0 to 20176
# Data columns (total 6 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   DATE                         20177 non-null  object
#  1   NUMBER OF ELECTRIC VEHICLES  20177 non-null  int64
#  2   VEHICLE MODEL YEAR           20177 non-null  int64
#  3   VEHICLE MAKE                 20177 non-null  object
#  4   LOCATION                     20177 non-null  object
#  5   VEHICLE MODEL                18208 non-null  object
# dtypes: int64(2), object(4)
# memory usage: 945.9+ KB

# %%
df['DATE'] = pd.to_datetime(df['DATE'])
df['YEAR'] = df['DATE'].dt.year
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20177 entries, 0 to 20176
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   DATE                         20177 non-null  datetime64[ns]
#  1   NUMBER OF ELECTRIC VEHICLES  20177 non-null  int64
#  2   VEHICLE MODEL YEAR           20177 non-null  int64
#  3   VEHICLE MAKE                 20177 non-null  object
#  4   LOCATION                     20177 non-null  object
#  5   VEHICLE MODEL                18208 non-null  object
#  6   YEAR                         20177 non-null  int32
# dtypes: datetime64[ns](1), int32(1), int64(2), object(3)
# memory usage: 1.0+ MB
# C:\Users\MALVA\AppData\Local\Temp\ipykernel_20404\3000821000.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# ...

# %%
# snake case for the dataframe columns
df.columns = df.columns.str.lower().str.replace(' ', '_')
df.head()
# Out:
#         date  number_of_electric_vehicles  vehicle_model_year vehicle_make  \
# 0 2021-10-01                            1                2006       TOYOTA
# 1 2021-10-01                            1                2008       TOYOTA
# 2 2021-10-01                            1                2009       NISSAN
# 3 2021-10-01                            1                2009       TOYOTA
# 4 2021-10-01                            1                2011      HYUNDAI
#
#           location vehicle_model  year
# 0   HALIFAX COUNTY           NaN  2021
# 1   HALIFAX COUNTY           NaN  2021
# 2  VICTORIA COUNTY           NaN  2021
# 3   HALIFAX COUNTY           NaN  2021
# 4   HALIFAX COUNTY           NaN  2021

# %%
# look for typos in the main dataframe
df['vehicle_make'].unique()
# Out:
# array(['TOYOTA', 'NISSAN', 'HYUNDAI', 'LEXUS', 'FORD', 'HONDA', 'ZERO',
#        'SMART', 'TESLA', 'BMW', 'CHEVROLET', 'KIA', 'VOLKSWAGEN', 'AUDI',
#        'MERCEDES BENZ', 'HISUN', 'JAGUAR', 'HARLEY DAVIDSON', 'MINI',
#        'PORSCHE', 'SUPER SOCO', 'MUSTANG', 'VOLVO', 'MITSUBISHI', 'JEEP',
#        'TELSA', 'CAN-AM', 'COLUMBIA', 'POLESTAR MOTOR VEHICLES', 'TINBOT',
#        'MOTREC', 'CLUB CAR', 'KAWASAKI', 'CHRYSLER', 'LUCID',
#        'INTERNATIONAL', 'FIAT', 'BOBCAT', 'SUBARU', 'TEREX', 'IDEAL',
#        'CATERPILLAR', 'MAZDA', 'CADILLAC', 'JOHN DEERE', 'DODGE',
#        'HOMEMADE', 'VER-MAC', 'GMC', 'NOVABUS', 'BIL-JAX', 'ASTEC',
#        'LINDER', 'GENESIS', 'TERRA MASTER', 'HAULOTTE',
#        'JUNGHEINRICH LIFT TRUCK', 'BMH', 'TENAX', 'RIVIAN', 'TOWABLE',
#        'JDJ', 'NORTHTRAIL', 'SOLAR ARROW',
#        'SURRON ELECTRIC OFF HWY BIKES', 'FISKER', 'BUCHER', 'CFMOTO',
#        'FCCC', 'ACURA', 'ORANGE EV', 'WESTWARD', 'KTM', 'CHEVEL',
# ...

# %%
# convert vehicle_make to lower and capital letter
df['vehicle_make'] = df['vehicle_make'].str.lower().str.strip().str.title()
df.head()
# Out:
#         date  number_of_electric_vehicles  vehicle_model_year vehicle_make  \
# 0 2021-10-01                            1                2006       Toyota
# 1 2021-10-01                            1                2008       Toyota
# 2 2021-10-01                            1                2009       Nissan
# 3 2021-10-01                            1                2009       Toyota
# 4 2021-10-01                            1                2011      Hyundai
#
#           location vehicle_model  year
# 0   HALIFAX COUNTY           NaN  2021
# 1   HALIFAX COUNTY           NaN  2021
# 2  VICTORIA COUNTY           NaN  2021
# 3   HALIFAX COUNTY           NaN  2021
# 4   HALIFAX COUNTY           NaN  2021

# %%
# Change Location and vehicle_model to lower() and capital letter
df['location'] = df['location'].str.lower().str.strip().str.title()
df['vehicle_model'] = df['vehicle_model'].str.lower().str.strip().str.title()
df.head(20)
# Out:
#          date  number_of_electric_vehicles  vehicle_model_year vehicle_make  \
# 0  2021-10-01                            1                2006       Toyota
# 1  2021-10-01                            1                2008       Toyota
# 2  2021-10-01                            1                2009       Nissan
# 3  2021-10-01                            1                2009       Toyota
# 4  2021-10-01                            1                2011      Hyundai
# 5  2021-10-01                            1                2011        Lexus
# 6  2021-10-01                            1                2012         Ford
# 7  2021-10-01                            1                2012        Honda
# 8  2021-10-01                            1                2012      Hyundai
# 9  2021-10-01                            4                2012       Nissan
# 10 2021-10-01                            1                2012       Nissan
# ...

# %%
# Replace nan values in column vehicle_model
df['vehicle_model'] = df['vehicle_model'].fillna("")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20177 entries, 0 to 20176
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   date                         20177 non-null  datetime64[ns]
#  1   number_of_electric_vehicles  20177 non-null  int64
#  2   vehicle_model_year           20177 non-null  int64
#  3   vehicle_make                 20177 non-null  object
#  4   location                     20177 non-null  object
#  5   vehicle_model                20177 non-null  object
#  6   year                         20177 non-null  int32
# dtypes: datetime64[ns](1), int32(1), int64(2), object(3)
# memory usage: 1.0+ MB

# %%
# Search typos in vehicle_model column
typos_model = df[~df['vehicle_model'].duplicated()]
typos_model
# Out:
#             date  number_of_electric_vehicles  vehicle_model_year  \
# 0     2021-10-01                            1                2006
# 1969  2024-01-22                            1                2024
# 1970  2024-01-22                            1                2023
# 1972  2024-01-22                            1                2024
# 1974  2024-01-22                            1                2023
# ...          ...                          ...                 ...
# 19921 2025-07-01                            1                2019
# 20037 2025-07-01                            1                2025
# 20043 2025-07-01                            1                2025
# 20046 2025-07-01                            1                2024
# 20050 2025-07-01                            1                2025
#
#       vehicle_make           location      vehicle_model  year
# 0           Toyota     Halifax County                     2021
# ...

# %%
# Store all typos in vehicle model to the vehicle maker, dictionary
typos_models_dict = {}
for index, rows in df.iterrows():
    current_year = rows["vehicle_model_year"]
    makers = rows["vehicle_make"]
    if current_year not in typos_models_dict:
        # initialize an emptry innerdictionary for this year
        typos_models_dict[current_year] = {}
    # filter the original dataframe (df) for non-null models of this maker and year
    known_models_df = df[
        (df["vehicle_model_year"] == current_year) &
        (df["vehicle_make"] == makers) &
        (df["vehicle_model"].notna())
        ]
        # get the unique models and convert to a list
    possible_models_list = known_models_df["vehicle_model"].unique().tolist()
    # add this maker and its list of possible models to the inner dictionary for the current year
    typos_models_dict[current_year][makers] = possible_models_list

typos_models_dict
# Out:
# {2006: {'Toyota': [''], 'John Deere': ['Gator']},
#  2008: {'Toyota': ['', 'Camry'], 'Kia': ['', 'Rio'], 'Lexus': ['', 'Rx']},
#  2009: {'Nissan': ['', 'Altima'], 'Toyota': ['', 'Camry']},
#  2011: {'Hyundai': ['', 'Sonata'],
#   'Lexus': ['', 'Rx'],
#   'Tesla': ['', 'Roadster'],
#   'Honda': ['Cr-Z']},
#  2012: {'Ford': ['', 'Focus'],
#   'Honda': ['', 'Insight'],
#   'Hyundai': [''],
#   'Nissan': ['', 'Leaf', 'Lvl'],
#   'Toyota': ['', 'Prius'],
#   'Zero': [''],
#   'Mitsubishi': ['', 'I Miev', 'I-Miev'],
#   'Chevrolet': ['', 'Volt'],
#   'Kawasaki': ['', 'Vn900'],
#   'Terex': ['Jaw Crusher'],
#   'Bil-Jax': ['5533.0A']},
#  2013: {'Nissan': ['', 'Leaf'],
#   'Smart': ['', 'Fortwo'],
#   'Tesla': ['', 'Model S', 'S'],
#   'Zero': ['', 'S'],
#   'Can-Am': [''],
#   'Bil-Jax': ['4527.0A'],
#   'Astec': ['Pss-412-60']},
#  2014: {'Bmw': ['', 'I3'],
#   'Chevrolet': ['', 'Spark', 'Volt', 'Spark Ev'],
#   'Ford': ['', 'Focus'],
#   'Nissan': ['', 'Leaf'],
# ...

# %%
year_2006 = typos_models_dict[2006]
year_2006
# Out:
# {'Toyota': [''], 'John Deere': ['Gator']}

# %%
for year, makers in typos_models_dict.items():
    for maker, models in makers.items():
        # Find a replacement model (any non-empty one)
        replacement = next((m for m in models if m != ""), None)

        # Replace all empty strings with the replacement
        typos_models_dict[year][maker] = [
            replacement if m == "" else m for m in models]
typos_models_dict
# Out:
# {2006: {'Toyota': [None], 'John Deere': ['Gator']},
#  2008: {'Toyota': ['Camry', 'Camry'],
#   'Kia': ['Rio', 'Rio'],
#   'Lexus': ['Rx', 'Rx']},
#  2009: {'Nissan': ['Altima', 'Altima'], 'Toyota': ['Camry', 'Camry']},
#  2011: {'Hyundai': ['Sonata', 'Sonata'],
#   'Lexus': ['Rx', 'Rx'],
#   'Tesla': ['Roadster', 'Roadster'],
#   'Honda': ['Cr-Z']},
#  2012: {'Ford': ['Focus', 'Focus'],
#   'Honda': ['Insight', 'Insight'],
#   'Hyundai': [None],
#   'Nissan': ['Leaf', 'Leaf', 'Lvl'],
#   'Toyota': ['Prius', 'Prius'],
#   'Zero': [None],
#   'Mitsubishi': ['I Miev', 'I Miev', 'I-Miev'],
#   'Chevrolet': ['Volt', 'Volt'],
#   'Kawasaki': ['Vn900', 'Vn900'],
#   'Terex': ['Jaw Crusher'],
#   'Bil-Jax': ['5533.0A']},
#  2013: {'Nissan': ['Leaf', 'Leaf'],
#   'Smart': ['Fortwo', 'Fortwo'],
#   'Tesla': ['Model S', 'Model S', 'S'],
#   'Zero': ['S', 'S'],
#   'Can-Am': [None],
#   'Bil-Jax': ['4527.0A'],
#   'Astec': ['Pss-412-60']},
#  2014: {'Bmw': ['I3', 'I3'],
# ...

# %%
models_in_total = df.groupby('vehicle_make')['vehicle_model'].unique().reset_index()
models_in_total
# Out:
#    vehicle_make                                      vehicle_model
# 0         Acura                                              [Zdx]
# 1         Astec                                       [Pss-412-60]
# 2          Audi  [, Q4E, Q8E Sb, Sq8 E, Q8 E, Q4 E, E-Tron, Q4,...
# 3       Bil-Jax                                 [4527.0A, 5533.0A]
# 4           Bmh                                            [Frame]
# ..          ...                                                ...
# 70      Ver-Mac                                  [St-4X8, St-4815]
# 71   Volkswagen  [, Id4, E Golf, Id 4, Taos, Id4 Awd, 1.0D4, Eg...
# 72        Volvo  [, Xc40, C40 Rch, C40, Xc40 Rch, Ede, Xc40 Rec...
# 73     Westward                                  [Utility Vehicle]
# 74         Zero    [, Fxs Zf6.5, Ds, Fx Zf7.2, Dsr Zf14.4, Dsr, S]
#
# [75 rows x 2 columns]

# %%
more_typos = models_in_total[models_in_total['vehicle_model'].apply(lambda x: len(x) > 2)]
more_typos
# Out:
#                vehicle_make                                      vehicle_model
# 2                      Audi  [, Q4E, Q8E Sb, Sq8 E, Q8 E, Q4 E, E-Tron, Q4,...
# 5                       Bmw  [, X3, I4 Edrive40, I4 Edrive35, I5, I4 M50, I...
# 8                  Cadillac  [Lyriq, Optiq, Escalade Iq, Escalade, Esciq, V...
# 13                Chevrolet  [, Bolt Euv, Blazer, Bolt, Blazer Ev, Blaev, V...
# 15                 Club Car                           [, Golf Cart, Mpt 1000E]
# 21                     Ford  [, F150 Lightning, F150, Trans, Trans Cargo, M...
# 23                      Gmc  [Hummer, Hummr, Hummer Ev, Hummer Suv, Sierra,...
# 25                 Haulotte                     [4527.0A, 5533.0A, Hta16P4527]
# 28                    Honda  [, Cr-V, Insight, Crv, Sc4324 Vt1100C2F4, Acco...
# 29                  Hyundai  [, Kona Ev, Ioniq 6, Ioniq 5, Ioniq6, Kona, Io...
# 32                   Jaguar          [, I-Pace, Ipace, Ev 400 Hse, L-Pace Hse]
# ...

# %%
for index, row in more_typos.iterrows():
    maker = row['vehicle_make']
    for model in row['vehicle_model']:
        print(f"Maker: {maker}, Model: {model}")
    #models = row['vehicle_model']
    #print(f"Maker: {maker}, Models: {models}")
# Out:
# Maker: Audi, Model:
# Maker: Audi, Model: Q4E
# Maker: Audi, Model: Q8E Sb
# Maker: Audi, Model: Sq8 E
# Maker: Audi, Model: Q8 E
# Maker: Audi, Model: Q4 E
# Maker: Audi, Model: E-Tron
# Maker: Audi, Model: Q4
# Maker: Audi, Model: R7 Se
# Maker: Audi, Model: Q4 E Sb
# Maker: Audi, Model: E-Tron Gt
# Maker: Audi, Model: Esv
# Maker: Audi, Model: R7Se
# Maker: Audi, Model: Q5E
# Maker: Audi, Model: Q5 E
# Maker: Audi, Model: Q8
# Maker: Audi, Model: Etr
# Maker: Audi, Model: Q5
# Maker: Audi, Model: Q4 E-Tron
# Maker: Audi, Model: Etro
# Maker: Audi, Model: A3
# Maker: Audi, Model: E-Tron Technik Quatt
# Maker: Audi, Model: E-Tro
# Maker: Audi, Model: Rs E-Tron Gt
# Maker: Audi, Model: E-Sb
# Maker: Audi, Model: Q6E
# Maker: Audi, Model: 3.0Ae
# Maker: Audi, Model: Q6
# Maker: Audi, Model: Q6 60E
# Maker: Bmw, Model:
# Maker: Bmw, Model: X3
# Maker: Bmw, Model: I4 Edrive40
# Maker: Bmw, Model: I4 Edrive35
# Maker: Bmw, Model: I5
# Maker: Bmw, Model: I4 M50
# ...

# %%
ev_typo_corrections = {
    "Tesla": {
        # Standard models and variants
        "model s": "Model S",
        "models": "Model S",
        "model-s": "Model S",
        "modle s": "Model S",
        "tesla model s": "Model S",
        "tesal model s": "Model S",
        "telsa model s": "Model S",
        "tesls model s": "Model S",
        "tesla s": "Model S",
        "modle s": "Model S",
        "model 3": "Model 3",
        "model3": "Model 3",
        "modle 3": "Model 3",
        "tesla modle 3": "Model 3",
        "tesla model3": "Model 3",
        "tesla model 3": "Model 3",
        "tesal model 3": "Model 3",
        "tesl model 3": "Model 3",
        "telsa model 3": "Model 3",
        "moddel 3": "Model 3",
        "model x": "Model X",
        "modelx": "Model X",
        "model-x": "Model X",
        "tesla modelx": "Model X",
        "modle x": "Model X",
        "tesal model x": "Model X",
        "telsa model x": "Model X",
        "moddel x": "Model X",
        "tesla model x": "Model X",
        "model y": "Model Y",
        "modely": "Model Y",
        "model-y": "Model Y",
        "tesla model y": "Model Y",
        "modle y": "Model Y",
        "tesal model y": "Model Y",
        "telsa model y": "Model Y",
        "moddel y": "Model Y",
        "modl y": "Model Y",
        "roodster": "Roadster",
        "rodster": "Roadster",
        "roadstar": "Roadster",
        "cyber truck": "Cybertruck",
        "cybertruck": "Cybertruck",
        "cybrtruck": "Cybertruck",
        "cybrtrk": "Cybertruck",
        "cybertruk": "Cybertruck",
        "cybertrck": "Cybertruck",
        "cybertruckk": "Cybertruck",
        # Brand typos
        "tesla": "Tesla",
        "telsa": "Tesla",
        "tesal": "Tesla",
        "tesls": "Tesla",
    },
    "Volkswagen": {
        # ID.3 family
        "id.3": "ID.3",
        "id3": "ID.3",
        "id 3": "ID.3",
        "id-3": "ID.3",
        "vw id3": "ID.3",
        "vw id-3": "ID.3",
        "vw id 3": "ID.3",
        "volkswagen id3": "ID.3",
        "volkswagon id3": "ID.3",
        "wolkswagen id3": "ID.3",
        # ID.4
        "id.4": "ID.4",
        "id4": "ID.4",
        "id 4": "ID.4",
        "id-4": "ID.4",
        "vw id4": "ID.4",
        "vw id-4": "ID.4",
        "vw id 4": "ID.4",
        "volkswagen id4": "ID.4",
        "volkswagon id4": "ID.4",
        "wolkswagen id4": "ID.4",
        "vwid4": "ID.4",
        # ID.5, ID.6, ID.7
        "id.5": "ID.5",
        "id 5": "ID.5",
        "id-5": "ID.5",
        "vw id5": "ID.5",
        "vw id-5": "ID.5",
        "vw id 5": "ID.5",
        "volkswagen id5": "ID.5",
        "id.6": "ID.6",
        "id6": "ID.6",
        "id 6": "ID.6",
        "id-6": "ID.6",
        "id.7": "ID.7",
        "id7": "ID.7",
        "id 7": "ID.7",
        "id-7": "ID.7",
        "vw id7": "ID.7",
        "vw id-7": "ID.7",
        "vw id 7": "ID.7",
        "gtiev": "GTI EV",
        "idbeetle": "ID Beetle",
        # ID Buzz
        "buzz": "ID. Buzz",
        "idbuzz": "ID. Buzz",
        "id buzz": "ID. Buzz",
        "vw idbuzz": "ID. Buzz",
        "vw id buzz": "ID. Buzz",
        "volkswagen id buzz": "ID. Buzz",
    },
    "Ford": {
        "mach-e": "Mustang Mach-E",
        "mach e": "Mustang Mach-E",
        "mache": "Mustang Mach-E",
        "mach-e gt": "Mustang Mach-E GT",
        "mach e gt": "Mustang Mach-E GT",
        "mach e g t": "Mustang Mach-E GT",
        "mustng mach-e": "Mustang Mach-E",
        "mustang mache": "Mustang Mach-E",
        "mustang mach e": "Mustang Mach-E",
        "mustangmach-e": "Mustang Mach-E",
        "mustange mach-e": "Mustang Mach-E",
        "mustang mach-e gt": "Mustang Mach-E GT",
        "mustange mach-e": "Mustang Mach-E",
        "mustang mac-e": "Mustang Mach-E",
        "mustang mach e": "Mustang Mach-E",
        "mustang mach-e": "Mustang Mach-E",
        "ford mach e": "Mustang Mach-E",
        "ford mustang mach e": "Mustang Mach-E",
        "mustangmach e": "Mustang Mach-E",
        "mustang e": "Mustang Mach-E",
        "mustang mche": "Mustang Mach-E",
        "f150 lightning": "F-150 Lightning",
        "f-150 lightning": "F-150 Lightning",
        "f150lightning": "F-150 Lightning",
        "ford lightning": "F-150 Lightning",
        "f 150 lightning": "F-150 Lightning",
        "f-150 lightening": "F-150 Lightning",
        "f-150 lightining": "F-150 Lightning",
        "e transit": "E-Transit",
        "etransit": "E-Transit",
        "e-transit": "E-Transit",
        "transitt": "E-Transit",
        # Explorer, Capri, Puma
        "explorer ev": "Explorer EV",
        "explorr ev": "Explorer EV",
        "ford explorer ev": "Explorer EV",
        "capri ev": "Capri EV",
        "gen-e": "Puma Gen-E",
    },
    "Chevrolet": {
        "bolt ev": "Bolt EV",
        "boltev": "Bolt EV",
        "chevy bolt ev": "Bolt EV",
        "chevy bolt": "Bolt EV",
        "chevybolt": "Bolt EV",
        "chevrolet bolt": "Bolt EV",
        "cheverolet bolt": "Bolt EV",
        "chevrolet boltt": "Bolt EV",
        "chevy boltt": "Bolt EV",
        "bolt euv": "Bolt EUV",
        "bolteuv": "Bolt EUV",
        "bolt euv": "Bolt EUV",
        "chevy euv": "Bolt EUV",
        "chevy bolt euv": "Bolt EUV",
        "equinox ev": "Equinox EV",
        "chevy equinox ev": "Equinox EV",
        "equnix": "Equinox EV",
        "equinax ev": "Equinox EV",
        "equinoxev": "Equinox EV",
        "silverado ev": "Silverado EV",
        "chevy silverado ev": "Silverado EV",
        "silverrado ev": "Silverado EV",
        "silveradoev": "Silverado EV",
        "blazer ev": "Blazer EV",
        "chevy blazer ev": "Blazer EV",
        "blazr ev": "Blazer EV",
        "menlow": "Menlo",
        "menlo": "Menlo",
        "camaro ev": "Camaro EV",
    },
    "Hyundai": {
        "ioniq 5": "Ioniq 5",
        "ioniq5": "Ioniq 5",
        "hyundai ioniq 5": "Ioniq 5",
        "ionik 5": "Ioniq 5",
        "ionik5": "Ioniq 5",
        "ioniq-5": "Ioniq 5",
        "ioniq five": "Ioniq 5",
        "hyundai ionic 5": "Ioniq 5",
        "ioniq five ev": "Ioniq 5",
        "ionq 5": "Ioniq 5",
        "ioniq v": "Ioniq 5",
        "hyundai ioniq5": "Ioniq 5",
        "hyundai ioniq5": "Ioniq 5",
        "ioniq 6": "Ioniq 6",
        "ioniq6": "Ioniq 6",
        "hyundai ioniq 6": "Ioniq 6",
        "hyundai ionic 6": "Ioniq 6",
        "ioniq-6": "Ioniq 6",
        "ioniq six": "Ioniq 6",
        "ionik 6": "Ioniq 6",
        "ionik6": "Ioniq 6",
        "ioniq vi": "Ioniq 6",
        "ioniq six ev": "Ioniq 6",
        "kona electric": "Kona Electric",
        "kona ev": "Kona Electric",
        "kona elektrik": "Kona Electric",
        "kona-e": "Kona Electric",
        "hyundai kona ev": "Kona Electric",
        "cnoa electric": "Kona Electric",
        "hyundai kona electric": "Kona Electric",
        "casper electric": "Casper Electric",
        "inster": "Casper Electric",
    },
    "Kia": {
        "ev6": "EV6",
        "ev 6": "EV6",
        "ev-6": "EV6",
        "kia ev6": "EV6",
        "eva6": "EV6",
        "kiav6": "EV6",
        "ev9": "EV9",
        "ev 9": "EV9",
        "kia ev9": "EV9",
        "ev5": "EV5",
        "evv5": "EV5",
        "ev4": "EV4",
        "ev-4": "EV4",
        "kea": "Kia",
        "kua": "Kia",
        "nia": "Niro EV",
        "niro ev": "Niro EV",
        "e-niro": "Niro EV",
        "eniro": "Niro EV",
        "nirow": "Niro EV",
        "niroev": "Niro EV",
        "nero ev": "Niro EV",
        "kia nero ev": "Niro EV",
        "nerro ev": "Niro EV",
        "kia niro": "Niro EV",
        "niro electrical": "Niro EV",
        "ray ev": "Ray EV",
        "bongo ev": "Bongo EV",
    },
    "Nissan": {
        "leaf": "Leaf",
        "nissan leaf": "Leaf",
        "nissanleaf": "Leaf",
        "nissan-leaf": "Leaf",
        "lep": "Leaf",
        "leef": "Leaf",
        "nison leaf": "Leaf",
        "nissan leef": "Leaf",
        "nisson leaf": "Leaf",
        "niissan leaf": "Leaf",
        "leaf nissan": "Leaf",
        "nissn leaf": "Leaf",
        "nissan leaf ev": "Leaf",
        "leaf ev": "Leaf",
        "nissian leaf": "Leaf",
        "nisssan leaf": "Leaf",
        "nisaan leaf": "Leaf",
        "leaf-nissan": "Leaf",
        "leaf by nissan": "Leaf",
        "nissan ariya": "Ariya",
        "ariya": "Ariya",
        "aryia": "Ariya",
        "aariya": "Ariya",
        "aria": "Ariya",
        "airya": "Ariya",
        "arriya": "Ariya",
        "micra ev": "Micra EV",
        "sakura": "Sakura",
        "townstar ev": "Townstar EV",
        "micraev": "Micra EV",
    },
    "Audi": {
        "e-tron": "e-tron",
        "etron": "e-tron",
        "e tron": "e-tron",
        "audi etron": "e-tron",
        "audi e-tron": "e-tron",
        "e-tron s": "e-tron S",
        "etron s": "e-tron S",
        "e-tron s": "e-tron S",
        "audi e-tron s": "e-tron S",
        "e-trons": "e-tron S",
        "e-tron gt": "e-tron GT",
        "etron gt": "e-tron GT",
        "etrongt": "e-tron GT",
        "audi e-tron gt": "e-tron GT",
        "e-tron sportback": "e-tron Sportback",
        "q4 e-tron": "Q4 e-tron",
        "q4 etron": "Q4 e-tron",
        "q4e-tron": "Q4 e-tron",
        "q4eTron": "Q4 e-tron",
        "q4 tron": "Q4 e-tron",
        "audi q4 e-tron": "Q4 e-tron",
        "q8 e-tron": "Q8 e-tron",
        "q8 etron": "Q8 e-tron",
        "q8e-tron": "Q8 e-tron",
        "q8eTron": "Q8 e-tron",
        "q8 etron": "Q8 e-tron",
        "audi q8 e-tron": "Q8 e-tron",
        "audi e tron s": "e-tron S",
        "audi e tron": "e-tron",
        "etron s": "e-tron S",
        "audie e-tron": "e-tron",
        "audie etron": "e-tron",
    },
    "BMW": {
        "i4": "i4",
        "bmw i4": "i4",
        "bmwi4": "i4",
        "i-4": "i4",
        "bmw i 4": "i4",
        "bmv i4": "i4",
        "i5": "i5",
        "bmw i5": "i5",
        "i7": "i7",
        "bmw i7": "i7",
        "ix": "iX",
        "i x": "iX",
        "i-x": "iX",
        "bmw ix": "iX",
        "ix3": "iX3",
        "ix 3": "iX3",
        "bmw ix3": "iX3",
        "iX 3": "iX3",
        "bmw x3 electric": "iX3",
        "bm iX3": "iX3",
        "bmw iX-3": "iX3",
        "bmw ix3m sport": "iX3 M Sport",
        "bmw ix3 sport": "iX3 M Sport",
        "bmw i-x3": "iX3",
        "bmw ixm3": "iX3 M Sport",
        "bmw ix3m": "iX3 M Sport",
        "bmw i x3": "iX3",
        "bmw x-i3": "iX3",
        "bmw ix3 sport edition": "iX3 M Sport",
        "bmw ix3m sport edition": "iX3 M Sport",
        "bmw ix3 m": "iX3 M Sport",
        "bmw iX 3": "iX3",
        "bmw ix3 sport inspiring": "iX3 M Sport",
        "bmw iX3 M": "iX3 M Sport",
        "bmw i-x3m sport": "iX3 M Sport",
        "bmw IX3M Sport": "iX3 M Sport",
        "i3": "i3",
        "bmw i3": "i3",
        "bmwi3": "i3",
        "i 3": "i3",
        "bmw ix2": "iX2",
        "ix2": "iX2",
    },
    "Mercedes-Benz": {
        "eqb": "EQB",
        "eq b": "EQB",
        "eq-b": "EQB",
        "mercedes eqb": "EQB",
        "mercedez eqb": "EQB",
        "eqc": "EQC",
        "eq c": "EQC",
        "eq-c": "EQC",
        "mercedes eqc": "EQC",
        "eqe": "EQE",
        "eq e": "EQE",
        "eq-e": "EQE",
        "mercedes eqe": "EQE",
        "eqs": "EQS",
        "eq s": "EQS",
        "eq-s": "EQS",
        "mercedes eqs": "EQS",
        "eqa": "EQA",
        "maybacheqs": "EQM (Mercedes-Maybach EQS SUV)",
        "eqc sedan": "EQC",
        "eqe sedan": "EQE sedan",
        "eqs sedan": "EQS sedan",
        "eqs suv": "EQS SUV",
        # eSprinter and eVito
        "esprinter": "eSprinter",
        "evito": "eVito",
    },
    "BYD": {
        "han": "Han EV",
        "hanev": "Han EV",
        "han ev": "Han EV",
        "byd han": "Han EV",
        "tang": "Tang EV",
        "tangev": "Tang EV",
        "tang ev": "Tang EV",
        "byd tang": "Tang EV",
        "dolphin": "Dolphin",
        "byd dolphin": "Dolphin",
        "dolfin": "Dolphin",
        "dolphen": "Dolphin",
        "dolphon": "Dolphin",
        "atp3": "Atto 3",
        "atto3": "Atto 3",
        "atto 3": "Atto 3",
        "byd atto3": "Atto 3",
        "build your dreams": "BYD",
        "b.y.d.": "BYD",
        "byde": "BYD",
        "yuan plus": "Yuan Plus",
        "yuan pro": "Yuan Up/Pro",
        "seal": "Seal",
        "byd seal": "Seal",
        "seel": "Seal",
        "seal ev": "Seal",
        "byd seel": "Seal",
        "seagull": "Seagull",
        "dolphin mini": "Dolphin Mini",
        "byd dolphin mini": "Dolphin Mini",
    },
    "XPeng": {
        "xpeng": "XPeng",
        "xpeng g3": "G3",
        "x-peng": "XPeng",
        "xpeng-g3": "G3",
        "g 3": "G3",
        "xpengg3": "G3",
        "p5": "P5",
        "xpeng p5": "P5",
        "p 5": "P5",
        "xpengp5": "P5",
        "p7": "P7",
        "xpeng p7": "P7",
        "p 7": "P7",
        "xpengp7": "P7",
        "g9": "G9",
        "xpeng g9": "G9",
    },
    "NIO": {
        "nio es6": "ES6",
        "e s 6": "ES6",
        "es-6": "ES6",
        "neo es6": "ES6",
        "nio es8": "ES8",
        "e s 8": "ES8",
        "es-8": "ES8",
        "neo es8": "ES8",
        "nio ec6": "EC6",
        "e c 6": "EC6",
        "ec-6": "EC6",
        "neo ec6": "EC6",
        "nio et7": "ET7",
        "e t 7": "ET7",
        "et-7": "ET7",
        "neo et7": "ET7",
        "nio et5": "ET5",
        "e t 5": "ET5",
        "et-5": "ET5",
        "neo et5": "ET5",
    },
    "Polestar": {
        "polestar 2": "Polestar 2",
        "polestar2": "Polestar 2",
        "polestar 3": "Polestar 3",
        "polestar3": "Polestar 3",
        "polestar 4": "Polestar 4",
        "polestar4": "Polestar 4",
    },
    "Rivian": {
        "r1t": "R1T",
        "r1 t": "R1T",
        "rivian r1t": "R1T",
        "rt1": "R1T",
        "rivion r1t": "R1T",
        "r1s": "R1S",
        "r1 s": "R1S",
        "rivian r1s": "R1S",
        "rs1": "R1S",
        "rivion r1s": "R1S",
        "edv": "EDV",
        "rivian truck": "R1T",
        "rivian suv": "R1S",
    },
    "Lucid": {
        "air": "Air",
        "lucid air": "Air",
        "airdream": "Air Dream Edition",
        "air dream": "Air Dream Edition",
        "lucid dream": "Air Dream Edition",
        "gravity": "Gravity",
        "lucid gravity": "Gravity",
        "lucid graviti": "Gravity",
        "lucid grvity": "Gravity",
        "gravty": "Gravity",
    },
    "VinFast": {
        "vf 8": "VF 8",
        "vf-8": "VF 8",
        "v f 8": "VF 8",
        "vinfast vf8": "VF 8",
        "vinfast v8": "VF 8",
        "vf 9": "VF 9",
        "vf-9": "VF 9",
        "v f 9": "VF 9",
        "vinfast vf9": "VF 9",
        "vinfast v9": "VF 9",
    },
    "Other": {
        # Common misattributions and catch-alls, e.g. Chinese startups and general accidents
        "rivien": "Rivian",
        "lucis": "Lucid",
        "lucidair": "Lucid Air",
        "canou": "Canoo",
        "fiatt": "Fiat",
        "500e": "500e",
        "fiskar": "Fisker",
        "oceanev": "Ocean",
        "porsh": "Porsche",
        "taykan": "Taycan",
        "minicoop": "Mini Cooper",
        "spectrerr": "Spectre",
        "subura": "Subaru",
        "solttera": "Solterra",
        "toyoda": "Toyota",
        "bz4x": "bZ4X",
        "volvoo": "Volvo",
        "xc-40": "XC40 Recharge",
        "ex-90": "EX90",
    }
}

# %% [markdown]
# 2006 TOTOYA, PRIUS
#
# 2007 club clar: MPT 1000E
#
# 2012 hyundai IONIQ
#
#   zero S ZF9.0
#
# 2013 cam-am COMMANDER
#
# 2014 hyundai SONATA HYBRID
#
# 2017 tesla MODEL 3
#
# 2018 mercedes benz EQC
#
# 2019 hisun SECTOR E1
#
#   mercedes benz EQC
#
#   tesla MODEL Y
#
# 2020 super soco TC MAX
#   tesla MODEL Y
#
# 2021 mustang MACH-E
#
#   tesla S PLAID
#
# 2022 tesla MODEL Y

# %%
# Function to correct typos in vehicle_model based on vehicle_make
def correct_vehicle_model(row):
    make = row['vehicle_make']
    model = row['vehicle_model'].lower().strip()
    
    if make in ev_typo_corrections:
        corrections = ev_typo_corrections[make]
        if model in corrections:
            return corrections[model]
    return row['vehicle_model']  # Return original if no correction found
df['vehicle_model'] = df.apply(correct_vehicle_model, axis=1)
df['vehicle_model'] = df['vehicle_model'].str.title().str.strip()
df.head(20)
# Out:
#          date  number_of_electric_vehicles  vehicle_model_year vehicle_make  \
# 0  2021-10-01                            1                2006       Toyota
# 1  2021-10-01                            1                2008       Toyota
# 2  2021-10-01                            1                2009       Nissan
# 3  2021-10-01                            1                2009       Toyota
# 4  2021-10-01                            1                2011      Hyundai
# 5  2021-10-01                            1                2011        Lexus
# 6  2021-10-01                            1                2012         Ford
# 7  2021-10-01                            1                2012        Honda
# 8  2021-10-01                            1                2012      Hyundai
# 9  2021-10-01                            4                2012       Nissan
# 10 2021-10-01                            1                2012       Nissan
# ...

# %%
print(df['vehicle_make'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20404\2069630764.py in ?()
# ----> 1 print(df[df['vehicle_make']=='Ford'].unique())
#
# c:\Users\MALVA\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'unique'
